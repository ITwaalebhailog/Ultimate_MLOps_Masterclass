# %%
# %sql
-- Create the training features table in your active schema
CREATE TABLE IF NOT EXISTS db_diabetes_ml.default.training_features (
    Pregnancies INT,
    Glucose INT,
    BloodPressure INT,
    SkinThickness INT,
    Insulin INT,
    BMI DOUBLE,
    DiabetesPedigreeFunction DOUBLE,
    Age INT,
    Outcome INT,
    timestamp TIMESTAMP
) USING DELTA;

-- Create the inference log table in your active schema
CREATE TABLE IF NOT EXISTS db_diabetes_ml.default.inference_payload_logs (
    Pregnancies INT,
    Glucose INT,
    BloodPressure INT,
    SkinThickness INT,
    Insulin INT,
    BMI DOUBLE,
    DiabetesPedigreeFunction DOUBLE,
    Age INT,
    Predicted_Outcome INT,
    Model_Version STRING,
    timestamp TIMESTAMP
) USING DELTA;
